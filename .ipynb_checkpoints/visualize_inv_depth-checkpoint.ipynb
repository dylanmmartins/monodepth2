# %%
# visualize np array of inverse depth
# written for 112920 dataset with depth prediction by network trained on 113020 recording

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
invdepth_path = r'/home/niell_lab/tmp/mono_worldcam2/models/weights_19/disps_freelymoving_split.npy'

# %%
invdepth_arr = np.load(invdepth_path)

# %%
np.shape(invdepth_arr)
# Out:
# (78708, 320, 384)

# %%
np.max(invdepth_arr[1,:,:])
# Out:
# 9.999992

# %%
frame5000_path = r'/home/niell_lab/data/freely_moving_ephys/depth_datasets/112920_fm1_worldcam/112920_G6H27P8LT_control_Rig2_fm1_WORLDdeinter_frame-018604.jpg'

# %%
frame5000 = plt.imread(frame5000_path)

# %%
plt.subplots(2,1)
plt.subplot(211)
plt.imshow(frame5000)
plt.title('frame-018604')
plt.subplot(212)
plt.imshow(invdepth_arr[0,:,:])
plt.colorbar()
plt.savefig('/home/niell_lab/Documents/monodepth2_eval_112920fm_frame-018604.jpg')

# %%
flat_frame = np.ndarray.flatten(invdepth_arr[50,:,:])

# %%
# flat_frame[flat_frame>2] = np.nan

# %%
plt.hist(flat_frame, bins=100)
# Out:
# (array([ 2162.,  2430.,  2102.,  1945.,  1661.,  1339.,  1180.,  1088.,
#           992.,  1081.,  1047.,  1067.,   947.,  1008.,   973.,   971.,
#          1003.,  1044.,  1019.,   973.,   979.,   951.,   959.,   969.,
#           918.,   973.,  1027.,  1161.,  1253.,  1141.,  1123.,  1112.,
#          1189.,  1188.,  1226.,  1240.,  1347.,  1474.,  1540.,  1719.,
#          1970.,  1768.,  1750.,  1682.,  1530.,  1412.,  1407.,  1453.,
#          1465.,  1664.,  1720.,  1836.,  1630.,  1650.,  1573.,  1303.,
#           919.,   767.,   739.,   797.,   930.,   790.,   580.,   513.,
#           511.,   435.,   410.,   388.,   382.,   392.,   403.,   429.,
#           391.,   353.,   367.,   277.,   314.,   320.,   343.,   324.,
#           322.,   341.,   362.,   371.,   396.,   375.,   343.,   346.,
#           370.,   379.,   433.,   461.,   521.,   564.,   641.,   746.,
#           967.,  1334.,  2335., 23865.]),
# ...

# %%
np.min(flat_frame)

# %%
test_frame = invdepth_arr[51,:,:] > 2

# %%
plt.imshow(test_frame, cmap='gray')
plt.colorbar()

# %%
plt.subplots(10,10, figsize=(15,15))
for i in range(1, 101):
    plt.subplot(10,10,i)
    plt.imshow(np.ma.masked_invalid(invdepth_arr[i,:,:]), cmap='magma')
    plt.axis('off')
plt.tight_layout()
plt.show()
plt.colorbar()
plt.safefig('/home/niell_lab/Documents/mono_worldcam2_eval_112920randframes.jpg')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-21-8c9e7faf3a17> in <module>
#       6 plt.tight_layout()
#       7 plt.show()
# ----> 8 plt.colorbar()
#       9 plt.safefig('/home/niell_lab/Documents/mono_worldcam2_eval_112920randframes.jpg')
#
# ~/anaconda3/envs/pytorch-depth/lib/python3.6/site-packages/matplotlib/pyplot.py in colorbar(mappable, cax, ax, **kw)
#    2186         mappable = gci()
#    2187         if mappable is None:
# -> 2188             raise RuntimeError('No mappable was found to use for colorbar '
#    2189                                'creation. First define a mappable such as '
#    2190                                'an image (with imshow) or a contour set ('
#
# RuntimeError: No mappable was found to use for colorbar creation. First define a mappable such as an image (with imshow) or a contour set (with contourf).

# %%
plt.figure(figsize=(15,15))
plt.imshow(invdepth_arr[50,:,:], cmap='magma')
plt.colorbar()

# %%
frame_order = []
for line in enumerate(open("splits/freelymoving/test_files.txt", "r")):
    frame_order.append(str(line).split(' ')[-2])

# %%
min(frame_order)
# Out:
# '000001'

# %%
max(frame_order)
# Out:
# '078708'

# %%
import matplotlib.animation as animation

# %%
fig = plt.figure()
fig.show()
for i in range(1,78708):
    this_frame = str(i).zfill(6)
    this_index = frame_order.index(this_frame)
    plt.imshow(invdepth_arr[this_index, :, :], cmap='magma')
    fig.canvas.draw()

# %%
plt.figure()
for i in range(3600):
    plt.imshow(ims[i])
    plt.pause(0.05)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-a797656d0f87> in <module>
#       1 plt.figure()
#       2 for i in range(3600):
# ----> 3     plt.imshow(ims[i])
#       4     plt.pause(0.05)
#       5 plt.show()
#
# ~/anaconda3/envs/pytorch-depth/lib/python3.6/site-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, filternorm, filterrad, resample, url, data, **kwargs)
#    2728         filternorm=filternorm, filterrad=filterrad, resample=resample,
#    2729         url=url, **({"data": data} if data is not None else {}),
# -> 2730         **kwargs)
#    2731     sci(__ret)
#    2732     return __ret
#
# ~/anaconda3/envs/pytorch-depth/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1445     def inner(ax, *args, data=None, **kwargs):
# ...

# %%
ani = animation.ArtistAnimation(fig, ims, interval=50, blit=True, repeat_delay=1000)
plt.show()
